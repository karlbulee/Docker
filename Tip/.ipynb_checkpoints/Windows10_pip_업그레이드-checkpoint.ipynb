# %% [markdown]
# # pip upgrade 명령어 안될 때

# %% [markdown]
# 1. https://bootstrap.pypa.io/get-pip.py을 python 파일로 저장
# 2. 저장한 경로로 설정 후 python get-pip.py 실행

# %% [markdown]
# # 성공 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 레퍼런스

# %% [markdown]
# - 구글 검색어
# 1. Unable to find resource t64.exe in package pip._vendor.distlib
#
# - 블로그
# 1. https://woogyun.tistory.com/698
