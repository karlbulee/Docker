# %% [markdown]
# # 데이터베이스 모델링

# %% [markdown]
# **데이터베이스 모델링**
# - 테이블의 구조를 미리 설계하는 개념
# - 프로젝트를 진행하기 위해서는 대표적으로 폭포수 모델을 사용하는데, 데이터베이스 모델링은 폭포수 모델의 업무 분석과 시스템 설계 단계에 해당함
# - 이 단계를 거치면 가장 중요한 데이터베이스 개체인 테이블 구조가 결정됨
# - 우리가 살고 있는 세상에서 사용되는 사물이나 작업을 DBMS의 데이터베이스 개체로 옮기기 위한 과정
# - 데이터베이스 모델링에는 정답이 없음
#
# **프로젝트**
# - 현실 세계에서 일어나는 업무를 컴퓨터 시스템으로 옮겨놓는 과정
# - 대규모 소프트웨어를 작성하기 위한 전체 과정
#
# **소프트웨어 개발 단계 폭포수 모델**
# 1. 프로젝트 계획
# 2. 업무 분석
# 3. 시스템 설계
# 4. 프로그램 구현
# 5. 테스트
# 6. 유지보수
#
# **데이터**
# - 하나하나의 단편적인 정보
#
# **테이블**
# - 회원이나 제품의 데이터를 입력하기 위해 표 형태로 표현한 것
#
# **데이터베이스**
# - 테이블이 저장되는 장소
#
# **DBMS**
# - 데이터베이스 관리 시스템 또는 소프트웨어
#
# **열**
# - 테이블의 세로
#
# **열 이름**
# - 각 열을 구분하기 위한 이름
#
# **데이터 형식**
# - 열에 저장될 데이터의 형식
#
# **행**
# - 실질적인 진짜 데이터
#
# **기본 키**
# - 각 행을 구분하는 유일한 열
#
# **SQL**
# - DBMS가 알아듣는 언어

# %% [markdown]
# ## MySQL 데이터베이스 모델링 구축

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 데이터베이스

# %% [markdown]
# **데이터베이스**
# - 데이터를 저장하는 공간
# - MySQL을 설치한 후에는 가장 먼저 데이터베이스를 준비해야 하고 데이터베이스 안에 테이블을 생성해야 함
# - 테이블은 2차원의 표 형태로 이루어져 있으며, 각 열에 해당하는 데이터를 한 행씩 입력/수정/삭제
# - 마지막으로 입력이 완료된 데이터를 조회해서 활용
#
# **DBMS 설치**
# - 데이터베이스를 구축하기 위해 DBMS를 설치
# - DBMS의 한 종류인 MySQL 설치 완료

# %% [markdown]
# ## 데이터베이스 만들기 성공결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **테이블 만들기**
# - 테이블 설계하기 : 열 이름과 데이터 형식 지정
# - 열 이름, 영문 이름, 데이터 형식, 문자의 최대 길이, 널 허용 안 함(Not Null)
# - 영문으로 만들 때 띄어쓰기는 하지 않는 것이 좋음

# %% [markdown]
# ## 테이블 생성 성공결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 데이터 입력 성공결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **데이터 활용하기**
# - SQL에서는 데이터베이스 활용하기 위해 주로 SELECT 문 사용

# %% [markdown]
# ## 데이터 활용 성공 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
