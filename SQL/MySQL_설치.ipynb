# %% [markdown]
# # 데이터베이스

# %% [markdown]
# **데이터베이스**
# - 데이터의 집합
#
# **DBMS**
# - 데이터베이스를 관리하고 운영하는 소프트웨어
# - MySQL, 오라클, SQL 서버, MariaDB 등
#
# **SQL**
# - DBMS에 데이터를 구축, 관리하고 활용하기 위해서 사용되는 언어
#
# **관계형 DBMS**
# - RDMS
# - 대부분의 DBMS가 RDBMS 형대로 사용
# - 테이블이라는 최소 단위로 구성
# - 테이블은 하나 이상의 열과 행으로 이루어져 있음

# %% [markdown]
# # MySQL 설치

# %% [markdown]
# **MySQL**
# - 오라클 사에서 제공하는 데이터베이스 관리 소프트웨어

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 성공 결과

# %% [markdown]
# ![image.png](attachment:image.png)
