# %% [markdown]
# # Window10 Ubuntu 설치

# %% [markdown]
# ## Microsoft Store

# %% [markdown]
# 1. Microsoft Store에 들어가서 Windows Terminal을 설치한다

# %% [markdown]
# ![image.png](attachment:image.png)git init

# %% [markdown]
# 2. Microsoft Store에 들어가서 Ubuntu 버전을 알맞게 설치한다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## WSL
