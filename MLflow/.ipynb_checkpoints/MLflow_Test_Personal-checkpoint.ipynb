# %% [markdown]
# # MLflow Test

# %% [markdown]
# 1. Anaconda 가상환경 설치(mlflow_Test)
# 2. pip install sklearn mlflow
# 3. 바탕화면에 mlflow_test 폴더 생성
# 4. examples에 있는 sklearn_elasticnet_wine 폴더 붙여넣기
# 5. mlflow run sklearn_elasticnet_wine -P alpha=0.5 실행
# 6. 결과 확인

# %% [markdown]
# ## 성공 결과

# %% [markdown]
# - mlruns라는 폴더가 생기며 고유 ID 생성
# - UI에서 확인 가능

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
