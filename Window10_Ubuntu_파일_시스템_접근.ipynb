# %% [markdown]
# # 우분투에서 윈도우10 파일 시스템 접근하기

# %% [markdown]
# - cd /mnt/c/Users/(Username)/Desktop 코드를 실행하면 바탕화면에 있는 파일에 접근할 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 윈도우10에서 우분투 파일 시스템 접근하기

# %% [markdown]
# - 검색에서 \\\\\wsl$ 치기
# - 아무 폴더 열어서 경로에 똑같이 치기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 우분투에서 시작 경로 고정하기

# %% [markdown]
# 1. cd ~ 홈 디렉토리로 이동
# 2. vi .bashrc 코드 실행
# 3. i를 눌러 Insert 모드로 변경 후 최하단에 cd (원하는 경로) 입력
# 4. Esc 누르고 :wq 입력
# 5. 우분투 재시작

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
